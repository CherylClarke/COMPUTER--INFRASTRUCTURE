# %% [markdown]
# # work from leatures and practical with Ian McLoughlin
# # using yfinance and datetime

# %%
# dates and times
import datetime as dt


# data frame , pulled in with yfinance anyway 
import pandas as pd

import yfinance as yf

# numerical arrays
import numpy as np

#plotting
import matplotlib.pyplot as plt

dat = yf.Ticker("MSFT")

# %%
dat = yf.Ticker("MSFT")

dat.info
# Out:
# {'address1': 'One Microsoft Way',
#  'city': 'Redmond',
#  'state': 'WA',
#  'zip': '98052-6399',
#  'country': 'United States',
#  'phone': '425 882 8080',
#  'website': 'https://www.microsoft.com',
#  'industry': 'Software - Infrastructure',
#  'industryKey': 'software-infrastructure',
#  'industryDisp': 'Software - Infrastructure',
#  'sector': 'Technology',
#  'sectorKey': 'technology',
#  'sectorDisp': 'Technology',
# ...

# %%
dat.calendar
# Out:
# {'Dividend Date': datetime.date(2026, 3, 12),
#  'Ex-Dividend Date': datetime.date(2026, 2, 19),
#  'Earnings Date': [datetime.date(2026, 1, 28)],
#  'Earnings High': 4.11521,
#  'Earnings Low': 3.56,
#  'Earnings Average': 3.90766,
#  'Revenue High': 81661025500,
#  'Revenue Low': 78581000000,
#  'Revenue Average': 80277350800}

# %%
dat.analyst_price_targets
# Out:
# {'current': 474.82,
#  'high': 730.0,
#  'low': 483.0,
#  'mean': 625.4096,
#  'median': 634.15}

# %%
dat.history(period='1mo')
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2025-11-17 00:00:00-05:00  507.500160  511.163287  503.966764  506.541931
# 2025-11-18 00:00:00-05:00  494.444589  502.040388  485.870639  492.867554
# 2025-11-19 00:00:00-05:00  489.184435  494.264923  481.927997  486.209991
# 2025-11-20 00:00:00-05:00  492.709991  493.570007  475.500000  478.429993
# 2025-11-21 00:00:00-05:00  478.500000  478.920013  468.269989  472.119995
# 2025-11-24 00:00:00-05:00  475.000000  476.899994  468.019989  474.000000
# 2025-11-25 00:00:00-05:00  474.070007  479.149994  464.890015  476.989990
# 2025-11-26 00:00:00-05:00  486.309998  488.309998  481.200012  485.500000
# 2025-11-28 00:00:00-05:00  487.600006  492.630005  486.649994  492.010010
# 2025-12-01 00:00:00-05:00  488.440002  489.859985  484.649994  486.739990
# 2025-12-02 00:00:00-05:00  486.720001  493.500000  486.320007  490.000000
# 2025-12-03 00:00:00-05:00  476.320007  484.239990  475.200012  477.730011
# ...

# %%
# for multiple tickers , with spaces to seperate each
Tickers = yf.Tickers('MSFT AAPL GOOG')

# %%
# to download 

yf.download(['MSFT', 'AAPL', 'GOOG'], period='1mo')
# Out:
# /tmp/ipykernel_1873/4142589433.py:3: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   yf.download(['MSFT', 'AAPL', 'GOOG'], period='1mo')
# [*********************100%***********************]  3 of 3 completed
# Price            Close                                High              \
# Ticker            AAPL        GOOG        MSFT        AAPL        GOOG
# Date
# 2025-11-17  267.459991  285.413788  506.541931  270.489990  294.327955
# 2025-11-18  267.440002  284.774200  492.867554  270.709991  289.246289
# 2025-11-19  268.559998  292.798950  486.209991  272.209991  304.051618
# 2025-11-20  266.250000  289.790955  478.429993  275.429993  306.689934
# 2025-11-21  271.489990  299.454620  472.119995  273.329987  303.761808
# 2025-11-24  275.920013  318.262360  474.000000  277.000000  319.591479
# 2025-11-25  276.970001  323.428986  476.989990  280.380005  328.455705
# 2025-11-26  277.549988  320.071167  485.500000  279.529999  324.778087
# ...

# %% [markdown]
# # the download() function

# %%
# get the data 
df = yf.download(['AAPL', 'MSFT', 'GOOG'], period='5d', interval='1h')

# to show
df
# Out:
# /tmp/ipykernel_1873/1566515033.py:2: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(['AAPL', 'MSFT', 'GOOG'], period='5d', interval='1h')
# [                       0%                       ]
# [*********************100%***********************]  3 of 3 completed
# Price                           Close                                High  \
# Ticker                           AAPL        GOOG        MSFT        AAPL
# Datetime
# 2025-12-09 14:30:00+00:00  277.700012  314.142487  490.470001  280.029999
# 2025-12-09 15:30:00+00:00  277.410004  314.619995  490.720001  278.000000
# 2025-12-09 16:30:00+00:00  277.875000  317.630798  489.950012  278.119995
# 2025-12-09 17:30:00+00:00  278.385010  318.670013  490.380005  278.739990
# 2025-12-09 18:30:00+00:00  278.690002  318.279999  490.890015  278.890015
# 2025-12-09 19:30:00+00:00  277.864990  317.920013  490.954987  278.750000
# ...

# %%
# the index

df.index

# shows UTC time zone at bottom
# pandas dataframe
# Out:
# DatetimeIndex(['2025-12-09 14:30:00+00:00', '2025-12-09 15:30:00+00:00',
#                '2025-12-09 16:30:00+00:00', '2025-12-09 17:30:00+00:00',
#                '2025-12-09 18:30:00+00:00', '2025-12-09 19:30:00+00:00',
#                '2025-12-09 20:30:00+00:00', '2025-12-10 14:30:00+00:00',
#                '2025-12-10 15:30:00+00:00', '2025-12-10 16:30:00+00:00',
#                '2025-12-10 17:30:00+00:00', '2025-12-10 18:30:00+00:00',
#                '2025-12-10 19:30:00+00:00', '2025-12-10 20:30:00+00:00',
#                '2025-12-11 14:30:00+00:00', '2025-12-11 15:30:00+00:00',
#                '2025-12-11 16:30:00+00:00', '2025-12-11 17:30:00+00:00',
#                '2025-12-11 18:30:00+00:00', '2025-12-11 19:30:00+00:00',
#                '2025-12-11 20:30:00+00:00', '2025-12-12 14:30:00+00:00',
#                '2025-12-12 15:30:00+00:00', '2025-12-12 16:30:00+00:00',
#                '2025-12-12 17:30:00+00:00', '2025-12-12 18:30:00+00:00',
# ...

# %% [markdown]
# # saving the data

# %%
# print data to csv
#https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.to_csv.html

print(df.to_csv())
# Out:
# Price,Close,Close,Close,High,High,High,Low,Low,Low,Open,Open,Open,Volume,Volume,Volume
# Ticker,AAPL,GOOG,MSFT,AAPL,GOOG,MSFT,AAPL,GOOG,MSFT,AAPL,GOOG,MSFT,AAPL,GOOG,MSFT
# Datetime,,,,,,,,,,,,,,,
# 2025-12-09 14:30:00+00:00,277.70001220703125,314.1424865722656,490.4700012207031,280.0299987792969,314.5715026855469,491.94000244140625,277.3500061035156,312.6199951171875,488.5000915527344,277.8900146484375,314.45001220703125,491.0199890136719,5341504,2063287,2206572
# 2025-12-09 15:30:00+00:00,277.4100036621094,314.6199951171875,490.7200012207031,278.0,315.2699890136719,491.1300048828125,277.0299987792969,313.5400085449219,489.8399963378906,277.70001220703125,314.1424865722656,490.4700012207031,2290151,1009941,858330
# 2025-12-09 16:30:00+00:00,277.875,317.63079833984375,489.95001220703125,278.1199951171875,317.67999267578125,492.1000061035156,277.20001220703125,314.4599914550781,489.95001220703125,277.4100036621094,314.6400146484375,490.7200012207031,1696929,1191496,760850
# ...

# %%
# to save data as csv into data folder 
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.to_csv.html

df.to_csv('../data/data.csv')

# %% [markdown]
# # dates and times
# # datetime
#
# https://docs.python.org/3/library/datetime.html

# %%
# current date and time 

# dt is datetime module and datetime is data structure in it called datetime 
# now() to find time and date for now

now = dt.datetime.now()

# display
now
# Out:
# datetime.datetime(2025, 12, 15, 23, 42, 53, 299198)

# %%
# to format date and time 


# now.strftime("%Y-%m-%d %H:%M:%S")
# mark out as neater format below

# %%
# neater and add csv (DOESNT NOT RECOMMENDING ADDING CSV LIKE THIS)
now.strftime("%Y%m%d %H%M%S.csv")
# Out:
# '20251215 234253.csv'

# %%
# file name 

# now.strftime("%Y%m%d %H%M%S") + ".csv"

# or to rename and put where you want 


# command (folder + file + extension)
# df.to_csv("../data/" + now.strftime("%Y%m%d %H%M%S") + ".csv")

# if above one is run again it will overright the current file with new information


# change now.strftime function to dt.datetime.now() and it will produce new file 
df.to_csv("../data/" + dt.datetime.now().strftime("%Y%m%d %H%M%S") + ".csv")

# %%
df.plot()
# Out:
# <Axes: xlabel='Datetime'>

# %%
# to check the columns
df.columns
# Out:
# MultiIndex([( 'Close', 'AAPL'),
#             ( 'Close', 'GOOG'),
#             ( 'Close', 'MSFT'),
#             (  'High', 'AAPL'),
#             (  'High', 'GOOG'),
#             (  'High', 'MSFT'),
#             (   'Low', 'AAPL'),
#             (   'Low', 'GOOG'),
#             (   'Low', 'MSFT'),
#             (  'Open', 'AAPL'),
#             (  'Open', 'GOOG'),
#             (  'Open', 'MSFT'),
#             ('Volume', 'AAPL'),
#             ('Volume', 'GOOG'),
#             ('Volume', 'MSFT')],
#            names=['Price', 'Ticker'])

# %%
# closing price for apple

df[( 'Close', 'AAPL')]
# Out:
# Datetime
# 2025-12-09 14:30:00+00:00    277.700012
# 2025-12-09 15:30:00+00:00    277.410004
# 2025-12-09 16:30:00+00:00    277.875000
# 2025-12-09 17:30:00+00:00    278.385010
# 2025-12-09 18:30:00+00:00    278.690002
# 2025-12-09 19:30:00+00:00    277.864990
# 2025-12-09 20:30:00+00:00    277.230011
# 2025-12-10 14:30:00+00:00    277.450012
# 2025-12-10 15:30:00+00:00    278.257690
# 2025-12-10 16:30:00+00:00    278.526489
# 2025-12-10 17:30:00+00:00    278.119995
# 2025-12-10 18:30:00+00:00    278.220001
# 2025-12-10 19:30:00+00:00    278.980011
# 2025-12-10 20:30:00+00:00    278.720001
# 2025-12-11 14:30:00+00:00    276.119995
# 2025-12-11 15:30:00+00:00    275.825012
# 2025-12-11 16:30:00+00:00    277.904999
# 2025-12-11 17:30:00+00:00    277.522614
# 2025-12-11 18:30:00+00:00    277.760010
# 2025-12-11 19:30:00+00:00    278.095001
# 2025-12-11 20:30:00+00:00    278.059998
# 2025-12-12 14:30:00+00:00    277.869995
# 2025-12-12 15:30:00+00:00    277.739990
# ...

# %%
# THEN TO PLOT THAT 
df[( 'Close', 'AAPL')].plot()
# Out:
# <Axes: xlabel='Datetime'>

# %%
# to get the closing prices for each company
df[[('Close', 'AAPL'), ('Close', 'GOOG'), ('Close', 'MSFT')]].plot()
# Out:
# <Axes: xlabel='Datetime'>

# %%
# instead of saying close for each stock name , can just check close
df['Close']
# Out:
# Ticker                           AAPL        GOOG        MSFT
# Datetime
# 2025-12-09 14:30:00+00:00  277.700012  314.142487  490.470001
# 2025-12-09 15:30:00+00:00  277.410004  314.619995  490.720001
# 2025-12-09 16:30:00+00:00  277.875000  317.630798  489.950012
# 2025-12-09 17:30:00+00:00  278.385010  318.670013  490.380005
# 2025-12-09 18:30:00+00:00  278.690002  318.279999  490.890015
# 2025-12-09 19:30:00+00:00  277.864990  317.920013  490.954987
# 2025-12-09 20:30:00+00:00  277.230011  317.790009  492.059998
# 2025-12-10 14:30:00+00:00  277.450012  318.739990  480.390015
# 2025-12-10 15:30:00+00:00  278.257690  318.600006  480.364990
# 2025-12-10 16:30:00+00:00  278.526489  317.075104  481.600006
# 2025-12-10 17:30:00+00:00  278.119995  316.700012  477.290009
# 2025-12-10 18:30:00+00:00  278.220001  318.609985  476.470001
# 2025-12-10 19:30:00+00:00  278.980011  320.510010  478.059998
# 2025-12-10 20:30:00+00:00  278.720001  320.850006  478.521515
# ...

# %%
# so to plot all closing prices(better than having to spell them all out)
df['Close'].plot()
# Out:
# <Axes: xlabel='Datetime'>

# %%
# create new figure and axis

fig, ax = plt.subplots()

# plot all closing prices

df['Close'].plot(ax=ax)

# current date and time (getting current time stamp)
now = dt.datetime.now()

# file name (creating a new filename based on new timestamp)
filename = "../plots/" + dt.datetime.now().strftime("%Y%m%d %H%M%S") + ".png"


# save figure to plots folder
fig.savefig(filename, dpi=300)

# reference: https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.savefig.html
# shows savefig function and explians how to use it 

# dpi is the pixels per inch , from lecture found that 300 is suitable amount for it to not look blocky
